# %% [markdown]
# <div style="background-color:	#103060; text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px">
# <h1 style="color:white">Database SamenZoeterMeerGezond</h1>
# <b style="color:white">Rogier Gernaat</b>
#     </div>
#
# <a name='start'></a>

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Inladen van de library's</strong>
# </div>

# %%
# !pip install mysql-connector-python
# pip install mysql
# !pip install pandas
# !pip install python-dotenv

# %%
import pandas as pd
import warnings
import mysql.connector
import os
from dotenv import load_dotenv

# Onderdruk de UserWarning
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Server Variabelen met .env</strong>
# </div>

# %%
load_dotenv()
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT', 3306)
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')
db_ssl_ca = os.getenv('DB_SSL_CA')

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken Databases</strong>
# </div>

# %%
# Connect to the database
conn = mysql.connector.connect(
    host=db_host,
    port=db_port,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

#Query the database
query = "SHOW Databases"
databases = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the data  
databases
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3    scraping_project
# 4                 sys

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken Tabellen</strong>
# </div>

# %%
# Connect to the database
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

#Query the database
query = "SHOW Tables"
tables = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the data
tables
# Out:
#     Tables_in_scraping_project
# 0                 activiteiten
# 1           activiteiten_nlzve
# 2   activiteiten_scheidingpunt
# 3             activiteiten_uit
# 4             activiteiten_zma
# 5             activiteiten_zte
# 6                     apps_ggd
# 7                    evie_data
# 8                    thuisarts
# 9            vierstroom_nieuws
# 10               workshops_zve

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken website</strong>
# </div>
# Vanaf hier kun je alle websites bekijken, tabel aanpassen kan uiteraard via de query

# %%
# Establish the connection to Azure MySQL
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

query = "SELECT * FROM activiteiten"
df_IZ = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display a sample of the data
df_IZ.head()
# Out:
#    id                                            Titel  \
# 0   1               Informatiebijeenkomst huisvesting
# 1   2            Bingo bij inZet Noordhove & Seghwaert
# 2   3  Ouderbijeenkomst over kinderen en schermgebruik
# 3   4          Training assertiviteit voor volwassenen
#
#                                                 Link Datum_numeriek  \
# 0  https://www.inzet-indewijk.nl/informatiebijeen...     2025-01-07
# 1  https://www.inzet-indewijk.nl/bingo-bij-inzet-...     2025-01-21
# 2  https://www.inzet-indewijk.nl/ouderbijeenkomst...     2025-01-08
# 3  https://www.inzet-indewijk.nl/training-asserti...     2025-04-07
#
#                  Datum_text  \
# 0   dinsdag, 7 januari 2025
# 1  dinsdag, 21 januari 2025
# 2  woensdag, 8 januari 2025
# 3     maandag, 7 april 2025
#
#                                         Beschrijving       Starttijd  \
# 0                 Stel al je vragen over huisvesting 0 days 10:00:00
# 1                                       Sla je slag! 0 days 14:00:00
# 2  in samenwerking met de mediaconsulent van Bibl... 0 days 09:30:00
# 3                           Leer voor jezelf opkomen 0 days 18:30:00
#
#          Eindtijd                                       Locatie  \
# 0 0 days 11:30:00  inZet Buytenwegh & De Leyens, Teldersrode 25
# 1 0 days 16:00:00   inZet Noordhove & Seghwaert, Petuniatuin 7a
# 2 0 days 11:30:00             Forum Zoetermeer, Stadhuisplein 1
# 3 0 days 21:00:00  inZet Buytenwegh & De Leyens, Teldersrode 25
#
#                                       URL_afbeelding  \
# 0  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 1  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 2  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 3  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
#
#                                   Extra_beschrijving
# 0  Heb jij vragen over huisvesting? Kom dan naar ...
# 1  Op dinsdag 21 januari 14.00 - 16.00 uur heeft ...
# 2  Bibliotheek Zoetermeer en inZet organiseren sa...
# 3  Durf je niet te zeggen wat je werkelijk vindt?...

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Loop voor het snel bekijken van alle tabellen achter elkaar</strong>
# </div>

# %%
# Establish the connection to Azure MySQL
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

# Haal alle tabellen op
show_tables_query = "SHOW TABLES"
tables_df = pd.read_sql(show_tables_query, conn)

# Loop door alle tabellen en haal gegevens op
for table in tables_df.iloc[:, 0]:
    query = f"SELECT * FROM {table}"
    df = pd.read_sql(query, conn)
    
    # Toon een voorbeeld van de gegevens per tabel
    print(f"Data van tabel: {table}")
    display(df.head(10))  # Eerste 10 rijen kan aanpassen naar een ander getal
    print("\n")

# connectie uitzettenm
conn.close()
# Out:
# Data van tabel: activiteiten
#    id                                              Titel  \
# 0   1                    Kinderlunch bij inZet Meerzicht
# 1   2              Bingo bij inZet Noordhove & Seghwaert
# 2   3                           Energie besparen in huis
# 3   4  De rol van de praktijkondersteuner huisarts (POH)
# 4   5                           Cursus Omgaan met Pubers
# 5   6            Training assertiviteit voor volwassenen
# 6   7                               Training Hotelouders
# 7   8                 Informatiebijeenkomst huisvesting
#
#                                                 Link Datum_numeriek  \
# 0  https://www.inzet-indewijk.nl/kinderlunch-bij-...     2025-01-15
# 1  https://www.inzet-indewijk.nl/bingo-bij-inzet-...     2025-01-21
# 2  https://www.inzet-indewijk.nl/energie-besparen...     2025-01-15
# 3  https://www.inzet-indewijk.nl/de-rol-van-de-pr...     2025-01-20
# 4  https://www.inzet-indewijk.nl/cursus-omgaan-me...     2025-02-03
# 5  https://www.inzet-indewijk.nl/training-asserti...     2025-04-07
# 6  https://www.inzet-indewijk.nl/training-hotelou...     2025-02-18
# 7  https://www.inzet-indewijk.nl/informatiebijeen...     2025-02-11
#
#                   Datum_text  \
# 0  woensdag, 15 januari 2025
# 1   dinsdag, 21 januari 2025
# 2  woensdag, 15 januari 2025
# 3   maandag, 20 januari 2025
# 4   maandag, 3 februari 2025
# 5      maandag, 7 april 2025
# 6  dinsdag, 18 februari 2025
# 7  dinsdag, 11 februari 2025
#
#                                         Beschrijving       Starttijd  \
# 0                        Samen koken met de diëtiste 0 days 12:30:00
# 1                                       Sla je slag! 0 days 14:00:00
# 2         Voorlichting door de consulenten duurzaam  0 days 14:00:00
# 3  Voorlichtingsbijeenkomst voor ouderen in Zoete... 0 days 13:30:00
# 4                      De ontwikkeling van een puber 0 days 19:30:00
# 5                           Leer voor jezelf opkomen 0 days 18:30:00
# 6           Handvaten die je helpen bij de opvoeding 0 days 18:30:00
# 7                 Stel al je vragen over huisvesting 0 days 13:00:00
#
#          Eindtijd                                            Locatie  \
# 0 0 days 14:00:00                     InZet Meerzicht, Uiterwaard 21
# 1 0 days 16:00:00        inZet Noordhove & Seghwaert, Petuniatuin 7a
# 2 0 days 16:00:00  InZet Buytenwegh & De Leyens, César Franckrode 64
# 3 0 days 15:00:00                     InZet Centrum, Rakkersveld 253
# 4 0 days 21:30:00       inZet Buytenwegh & De Leyens, Teldersrode 25
# 5 0 days 21:00:00       inZet Buytenwegh & De Leyens, Teldersrode 25
# 6 0 days 20:30:00       inZet Buytenwegh & De Leyens, Teldersrode 25
# 7 0 days 14:30:00       inZet Buytenwegh & De Leyens, Teldersrode 25
#
#                                       URL_afbeelding  \
# 0  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 1  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 2  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 3  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 4  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 5  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 6  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 7  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
#
#                                   Extra_beschrijving
# 0  Op woensdagmiddag 15 januari is de diëtiste va...
# 1  Op dinsdag 21 januari 14.00 - 16.00 uur heeft ...
# 2  Ook in 2025 is onze energierekening nog steeds...
# 3  Met de vergrijzing van de bevolking groeit de ...
# 4  Veel ouders ervaren de puberteit als een lasti...
# 5  Durf je niet te zeggen wat je werkelijk vindt?...
# 6  Jouw zoon of dochter is 18 jaar of ouder en wo...
# 7  Heb jij vragen over huisvesting? Kom dan naar ...
# Data van tabel: activiteiten_nlzve
#                           Titel Locatie            Begintijd  \
# 0                   Atelier VZC  Online  21-01-2025 om 13:30
# 1  Webinar over voorzorgcirkels  Online  18-02-2025 om 12:00
# 2                   Atelier VZC          18-03-2025 om 13:30
# 3                   Atelier VZC  Online  13-05-2025 om 13:30
# 4  Lunchwebinar Voorzorgcirkels  Online  08-04-2025 om 12:00
# 5  Lunchwebinar Voorzorgcirkels  Online  10-06-2025 om 12:00
#
#               Eindtijd                                  Beschrijving_kort  \
# 0  21-01-2025 om 15:30  Heb jij gehoord van voorzorgcirkels, ben je ni...
# 1  18-02-2025 om 13:00  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 2  18-03-2025 om 15:30  Praktijktraining: Hoe start je een voorzorgcir...
# 3  13-05-2025 om 15:30  Praktijktraining: Hoe start je een voorzorgcir...
# 4  08-04-2025 om 13:00  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 5  10-06-2025 om 13:00  Maak kennis met voorzorgcirkel-pioniers en lee...
#
#                                    Beschrijving_lang  \
# 0  Heb jij gehoord van voorzorgcirkels, ben je ni...
# 1  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 2  Praktijktraining: Hoe start je een voorzorgcir...
# 3  Praktijktraining: Hoe start je een voorzorgcir...
# 4  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 5  Maak kennis met voorzorgcirkel-pioniers en lee...
#
#                                                 Link  \
# 0  https://www.nlzve.nl/agenda/2875128.aspx?t=Ate...
# 1  https://www.nlzve.nl/agenda/2875129.aspx?t=Web...
# 2  https://www.nlzve.nl/agenda/2955210.aspx?t=Ate...
# 3  https://www.nlzve.nl/agenda/2955212.aspx?t=Ate...
# 4  https://www.nlzve.nl/agenda/2955215.aspx?t=Lun...
# 5  https://www.nlzve.nl/agenda/2955216.aspx?t=Lun...
#
#                                       Afbeelding_url
# 0  https://www.nlzve.nl/media/sectionimages/a3318...
# 1  https://www.nlzve.nl/media/sectionimages/a3318...
# 2  https://www.nlzve.nl/media/sectionimages/a3318...
# 3  https://www.nlzve.nl/media/sectionimages/a3318...
# 4  https://www.nlzve.nl/media/sectionimages/a3318...
# 5  https://www.nlzve.nl/media/sectionimages/a3318...
# Data van tabel: activiteiten_scheidingpunt
#    id                                            titel  \
# 0   1                              Stoere Schildpadden
# 1   2                                   Dappere Dino’s
# 2   3                 KIESgroep voor Primair Onderwijs
# 3   4                   KIESgroep Voortgezet Onderwijs
# 4   5                                     Villa Pinedo
# 5   6     Informatiebijeenkomst voor gescheiden ouders
# 6   7              Online ouderschapscursus Ouders Inc
# 7   8           Online ouderbijeenkomst over scheiding
# 8   9  Houd me Vast: voor stellen met relatieproblemen
# 9  10               Contactgroep voor Verstoten ouders
#
#                                                 link  \
# 0  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 1  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 2  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 3  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 4  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 5  https://www.scheidingspunt.nl/agenda-volwassen...
# 6  https://www.scheidingspunt.nl/agenda-volwassen...
# 7  https://www.scheidingspunt.nl/agenda-volwassen...
# 8  https://www.scheidingspunt.nl/agenda-volwassen...
# 9  https://www.scheidingspunt.nl/agenda-volwassen...
#
#                                                  wat  \
# 0                                    Groepstraining.
# 1                                    Groepstraining.
# 2                   Spel- en lotgenotencontactgroep.
# 3                  Doe- en praatgroep voor jongeren.
# 4              Online buddyproject en ondersteuning.
# 5     Informatiebijeenkomsten voor gescheiden ouders
# 6  Online programma dat (aanstaande) ouders helpt...
# 7  Een online bijeenkomst over hoe kinderen en sc...
# 8  Groepstraining voor stellen om de relatie te v...
# 9                Contactgroep voor verstoten ouders.
#
#                                             voor_wie  \
# 0  Kinderen van 4 tot 6 jaar waarvan de ouders ga...
# 1  Kinderen van 6 tot 8 jaar waarvan de ouders ga...
# 2  Kinderen van 8 t/m 12 jaar waarvan de ouders g...
# 3  Kinderen uit klas 1 t/m 3 waarvan de ouders ga...
# 4  Kinderen 10 – 23 jaar waarvan ouders gaan sche...
# 5  Voor ouders die voor, tijdens of na de scheidi...
# 6  Voor zwangeren en ouders met kinderen van 0-4 ...
# 7  Voor alle gescheiden ouders, professionals en ...
# 8         Voor stellen die relatieproblemen ervaren.
# 9  Voor ouders die hun kind(eren) niet meer, of h...
#
#                                              wanneer
# 0      Voorjaar 2025, start woensdagmiddag 19 maart.
# 1      Voorjaar 2025, start woensdagmiddag 19 maart.
# 2            Start donderdagmiddag 20 februari 2025.
# 3                  Start bij voldoende aanmeldingen!
# 4                        Gehele jaar, naar behoefte.
# 5     Iedere 3e woensdag in de maand en de week erna
# 6  In eigen tempo, thuis op de bank wanneer julli...
# 7                          Vrijdag 13 december 2024.
# 8  Bij aanmelding van min. 4 stellen start HMV z....
# 9  Iedere eerste woensdagavond van de maand met u...
# Data van tabel: activiteiten_uit
#    id                                      Titel  \
# 0   1  Veldhuis & Kemper - Kunnen het niet laten
# 1   2                 Expositie 'Human Interest'
# 2   3           Remko Vrijdag - Vrijdag Doemsdag
# 3   4                   Remy Evers - Stoorzender
# 4   5             Projectkoor Black Gospel Music
# 5   6                    Klaverblad Polsstokgala
# 6   7       Isabelle Beernaert - La Dame En Noir
# 7   8        Edsilia Rombley - Love Songs & More
# 8   9      Tasting Whisky: Sherry - Storytellers
# 9  10                 Cultuurcafé Sieraden maken
#
#                                         Beschrijving  \
# 0  Hoeveel roze olifanten staan in jouw kamer? Of...
# 1  Human Interest gaat over verhalen die mensen r...
# 2  In deze solovoorstelling deelt Remko zijn visi...
# 3  Een absurdistisch spektakel over een energieke...
# 4  Na de succesvolle workshop “Wow, Taste and See...
# 5  Wil je topatletiek zien in Zoetermeer? Op zate...
# 6  Met dans en live percussie voel je de aarde's ...
# 7  Edsilia Rombley brengt in 'Love Songs & More' ...
# 8  Welkom in de wereld van de whisky. Ga mee op e...
# 9  Tijdens dit Cultuurcafé gaan we sieraden maken...
#
#                          Datum     Starttijd   Eindtijd    Prijs  \
# 0      Vrijdag 17 januari 2025  om 20.00 uur       None     None
# 1  Dagelijks t/m 16 maart 2025         11.00  17.00 uur   Gratis
# 2                    Dagelijks  om 20.00 uur       None     None
# 3     Zaterdag 18 januari 2025  om 20.30 uur       None     None
# 4    Dagelijks t/m 21 mei 2025         19.30  22.00 uur  € 95,00
# 5     Zaterdag 18 januari 2025         13.00  21.00 uur   Gratis
# 6     Zaterdag 18 januari 2025  om 20.00 uur       None     None
# 7    Donderdag 30 januari 2025  om 20.00 uur       None     None
# 8       Zondag 19 januari 2025         13.00  17.00 uur     None
# 9      Vrijdag 31 januari 2025         14.30  16.00 uur   Gratis
#
#                    Straat            Postcode                       Naam  \
# 0         Theaterplein 10  2711 EK Zoetermeer
# 1         Vlamingstraat 1  2712 BZ Zoetermeer          kunstgarage Franx
# 2         Theaterplein 10  2711 EK Zoetermeer
# 3         Theaterplein 10  2711 EK Zoetermeer
# 4         Leidsewallen 80  2722 PC Zoetermeer                        CKC
# 5  Van der Hagenstraat 36   2722NT Zoetermeer  ARV ILION - Van Tuyllpark
# 6         Theaterplein 10  2711 EK Zoetermeer
# 7         Theaterplein 10  2711 EK Zoetermeer
# 8         Theaterplein 10  2711 EK Zoetermeer
# 9         Nathaliegang 81  2719 CP Zoetermeer  Wijkbibliotheek Rokkeveen
#
#                            Email                      Bedrijf_Website  \
# 0   servicebalie@stadstheater.nl              https://stadstheater.nl
# 1       info@kunstgaragefranx.nl       http://www.kunstgaragefranx.nl
# 2   servicebalie@stadstheater.nl              https://stadstheater.nl
# 3   servicebalie@stadstheater.nl              https://stadstheater.nl
# 4  gospelchoirlifeline@gmail.com  https://www.lifelinegospelchoir.nl/
# 5            sponsoring@ilion.nl           http://www.polsstokgala.nl
# 6   servicebalie@stadstheater.nl              https://stadstheater.nl
# 7   servicebalie@stadstheater.nl              https://stadstheater.nl
# 8   servicebalie@stadstheater.nl              https://stadstheater.nl
# 9     esther@wijck-zoetermeer.nl       http://www.wijck-zoetermeer.nl
#
#                                          Url_plaatje
# 0  https://assets.plaece.nl/thumb/GL2lVWczl-MJJQ2...
# 1  https://assets.plaece.nl/thumb/IZ2jvmxsUHET3Cv...
# 2  https://assets.plaece.nl/thumb/Bn4l4fAmhIjCwon...
# 3  https://assets.plaece.nl/thumb/r4TwTQZFwflLLw8...
# 4  https://assets.plaece.nl/thumb/0P8sf4hg54iTNe9...
# 5  https://assets.plaece.nl/thumb/g6XI4rItjrX67e7...
# 6  https://assets.plaece.nl/thumb/c9JfNN4AYTXiLVm...
# 7  https://assets.plaece.nl/thumb/yILbzDql-Hi3DGs...
# 8  https://assets.plaece.nl/thumb/2K8bnD9FTjmFDZs...
# 9  https://assets.plaece.nl/thumb/TeB9wxZRfmzD_OJ...
# Data van tabel: activiteiten_zma
#    id                                              Titel  \
# 0   1                    Kinderlunch bij inZet Meerzicht
# 1   2                  Lunchpauzeconcert Joram van Ketel
# 2   3      Bijeenkomst energie besparen inZet Buytenwegh
# 3   4                             JAMSESSIE ROCK 'N ROLL
# 4   5                     Projectkoor Black Gospel Music
# 5   6        Stamppot buffet bij De Goede Buur De Leyens
# 6   7                                           Recharge
# 7   8                                   Vrijdag Doemsdag
# 8   9  Start bingo seizoen 2025/2026 buurtvereniging ...
# 9  10                                 I'M STILL STANDING
#
#                                                 Link  \
# 0  https://zoetermeeractief.nl/agenda/complete-ag...
# 1  https://zoetermeeractief.nl/agenda/complete-ag...
# 2  https://zoetermeeractief.nl/agenda/complete-ag...
# 3  https://zoetermeeractief.nl/agenda/complete-ag...
# 4  https://zoetermeeractief.nl/agenda/complete-ag...
# 5  https://zoetermeeractief.nl/agenda/complete-ag...
# 6  https://zoetermeeractief.nl/agenda/complete-ag...
# 7  https://zoetermeeractief.nl/agenda/complete-ag...
# 8  https://zoetermeeractief.nl/agenda/complete-ag...
# 9  https://zoetermeeractief.nl/agenda/complete-ag...
#
#                                         Beschrijving          Startdatum  \
# 0  Op woensdagmiddag 15 januari is de diëtiste va...  januari 15,  12:30
# 1  Joram en Iddo vormen een avontuurlijk duo op t...  januari 15,  12:45
# 2  Ook in 2025 is onze energierekening nog steeds...  januari 15,  14:00
# 3  Deze avond is het podium open voor iedere muzi...  januari 15,  20:00
# 4  Na de succesvolle workshop “Wow, Taste and See...  januari 15,  19:30
# 5  De Goede Buur De Leyens organiseert op maandag...  januari 15,  17:00
# 6  Recharge is een jonge formatie bestaande uit e...  januari 17,  20:30
# 7  Het moest er natuurlijk een keer van komen: Re...  januari 15,  20:00
# 8  Buurtvereniging Buytenrode organiseert zoals g...  januari 15,  19:00
# 9  Dit theaterseizoen komt er een droom voor mij ...  januari 16,  20:00
#
#                                Url_header_afbeelding  \
# 0  https://zoetermeeractief.nl/agenda/complete-ag...
# 1  https://zoetermeeractief.nl/images/imagesevent...
# 2  https://zoetermeeractief.nl/agenda/complete-ag...
# 3  https://zoetermeeractief.nl/images/images/even...
# 4  https://zoetermeeractief.nl/images/images/even...
# 5  https://zoetermeeractief.nl/agenda/complete-ag...
# 6  https://zoetermeeractief.nl/images/imagesevent...
# 7  https://zoetermeeractief.nl/images/imagesevent...
# 8  https://zoetermeeractief.nl/images/images/even...
# 9  https://zoetermeeractief.nl/images/imagesevent...
#
#                                   Extra_beschrijving  \
# 0  Op woensdagmiddag 15 januari is de diëtiste va...
# 1  Joram en Iddo vormen een avontuurlijk duo op t...
# 2  Ook in 2025 is onze energierekening nog steeds...
# 3  Deze avond is het podium open voor iedere muzi...
# 4  Na de succesvolle workshop “Wow, Taste and See...
# 5  De Goede Buur De Leyens organiseert op maandag...
# 6  Recharge is een jonge formatie bestaande uit e...
# 7  Het moest er natuurlijk een keer van komen: Re...
# 8  Buurtvereniging Buytenrode organiseert zoals g...
# 9  Dit theaterseizoen komt er een droom voor mij ...
#
#                                       Url_afbeelding   Categorie_1  \
# 0  https://zoetermeeractief.nl/images/Zoetermeern...  Activiteiten
# 1                                               None        Muziek
# 2  https://zoetermeeractief.nl/images/Zoetermeern...  Activiteiten
# 3                                               None        Muziek
# 4                                               None  Activiteiten
# 5  https://zoetermeeractief.nl/images/Zoetermeern...  Activiteiten
# 6                                               None        Muziek
# 7                                               None       Theater
# 8                                               None  Activiteiten
# 9                                               None        Muziek
#
#                 Categorie_2 Categorie_3 Categorie_4
# 0                 Meerzicht       Jeugd        None
# 1  Oude Kerk Concerten logo        None        None
# 2                Buytenwegh        None        None
# 3       JJ Music House logo        None        None
# 4           Activiteit logo        None        None
# 5                 De Leyens        None        None
# 6         De Boerderij logo        None        None
# 7         Stadstheater logo        None        None
# 8           Activiteit logo        None        None
# 9         Stadstheater logo        None        None
# Data van tabel: activiteiten_zte
#    id                                              Titel  \
# 0   1         Welke straat is de liefste van Zoetermeer?
# 1   2       Community aan het woord: Sociale sportschool
# 2   3  Interview: Karaokeavond voor Hindoestaanse gem...
# 3   4  Samen wandelen in het groen zorgt voor verbind...
# 4   5                     Activiteit: Summer Sing Alongs
# 5   6              Terugblik Week tegen Eenzaamheid 2024
# 6   7               Community aan het woord: Gil Lieveld
# 7   8            Community aan het woord: Love Your Mind
# 8   9  Netwerkbijeenkomst: Eten en Ontmoeten in Buyte...
# 9  10            Community aan het woord: Interesse café
#
#                                                 Link  \
# 0  https://zoetermeertegeneenzaamheid.nl/nieuws/l...
# 1  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 2  https://zoetermeertegeneenzaamheid.nl/nieuws/i...
# 3  https://zoetermeertegeneenzaamheid.nl/nieuws/s...
# 4  https://zoetermeertegeneenzaamheid.nl/nieuws/a...
# 5  https://zoetermeertegeneenzaamheid.nl/nieuws/w...
# 6  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 7  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 8  https://zoetermeertegeneenzaamheid.nl/nieuws/n...
# 9  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
#
#                                Url_header_afbeelding Datum_numeriek  \
# 0  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-20
# 1  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-08-26
# 2  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-07-15
# 3  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-06-17
# 4  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-07-29
# 5  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-10-10
# 6  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-04
# 7  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-14
# 8  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-06-17
# 9  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-04-23
#
#                    Datum_text  \
# 0   woensdag 20 november 2024
# 1    maandag 26 augustus 2024
# 2        maandag 15 juli 2024
# 3        maandag 17 juni 2024
# 4        maandag 29 juli 2024
# 5   donderdag 10 oktober 2024
# 6     maandag 4 november 2024
# 7  donderdag 14 november 2024
# 8        maandag 17 juni 2024
# 9       dinsdag 23 april 2024
#
#                                       Url_afbeelding  \
# 0  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 1  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 2  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 3  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 4  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 5  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 6  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 7  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 8  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 9  https://zoetermeertegeneenzaamheid.nl/media/fi...
#
#                                         Beschrijving
# 0  Lief en Leed Zoetermeer startte in 2020 met de...
# 1  De Sociale Sportschool brengt senioren en jong...
# 2  Tijdens de karaokeavond kun je genieten van ou...
# 3  Samen wandelen is gezelliger dan alleen! Daaro...
# 4  De zomer is niet voor iedereen een leuke tijd,...
# 5  De Zoetermeerse Community tegen Eenzaamheid or...
# 6  Mijn naam is Gil Lieveld en ik ben een onderne...
# 7  Wij zijn Radha Nanhoe en Steven van der Knaap....
# 8  Gado gado, gevulde wijnbladeren, pindasaus, ri...
# 9  Het Interessecafé Doe je graag dingen die jouw...
# Data van tabel: apps_ggd
#    id                   App_naam  App_rating  \
# 0   1               Villa Pinedo         5.0
# 1   2                     OOPOEH         5.0
# 2   3              Sound & Happy         5.0
# 3   4                  Care-Free         5.0
# 4   5            Klup Social app         4.5
# 5   6  Insight Timer - Meditatie         4.5
# 6   7                  soChicken         4.0
# 7   8                    Happify         4.5
# 8   9                     Fjaere         4.0
# 9  10         Meditation Moments         4.5
#
#                                    Beschrijving_kort  \
# 0  Villa Pinedo is een app voor kinderen met gesc...
# 1  Met behulp van de informatie, die de website w...
# 2  Met behulp van deze site kan je een kort muzie...
# 3  Een app over kindermishandeling en hoe kindere...
# 4  Klup is een sociale app voor 50-plussers. Op e...
# 5  Insight Timer is een meditatie en mindfulness-...
# 6  soChicken kan je helpen met een gelukkig en ge...
# 7  Happify is een Engelstalige app die je door da...
# 8  In deze app kan je al je uitvaartwensen en geg...
# 9  Meditation Moments is een Nederlandstalige app...
#
#                                    Beschrijving_lang  Dagelijks_Functioneren  \
# 0  Villa Pinedo is de plek waar kinderen met gesc...                       0
# 1  Stichting OOPOEH – Opa's en Oma's Passen Op Ee...                       0
# 2  Op een makkelijke manier kan je overal wanneer...                       0
# 3  Care-Free is een app over kindermishandeling v...                       1
# 4  Klup is een sociale app voor 50-plussers die o...                       0
# 5  Inzicht Timer biedt je geleide meditaties, lez...                       0
# 6  In de app staan interessante artikelen met han...                       1
# 7  In de app Happify kiest de gebruiker persoonli...                       0
# 8  Fjaere zorgt ervoor dat alle persoonlijke wens...                       0
# 9  De app is opgebouwd rondom momenten op een dag...                       1
#
#    Kwaliteit_van_Leven  Lichaamsfuncties  Meedoen  Mentaal_Welbevinden  \
# 0                    0                 0        0                    1
# 1                    0                 1        1                    0
# 2                    1                 0        0                    1
# 3                    1                 1        1                    1
# 4                    1                 0        1                    0
# 5                    0                 0        0                    1
# 6                    1                 0        0                    0
# 7                    1                 0        0                    1
# 8                    1                 0        0                    1
# 9                    1                 1        0                    1
#
#    Zingeving                                       Android_link  \
# 0          1  https://play.google.com/store/apps/details?id=...
# 1          1                                               None
# 2          1                                               None
# 3          1  https://play.google.com/store/apps/details?id=...
# 4          1  https://play.google.com/store/apps/details?id=...
# 5          1  https://play.google.com/store/apps/details?id=...
# 6          1  https://play.google.com/store/apps/details?id=...
# 7          1  https://play.google.com/store/apps/details?id=...
# 8          1  https://play.google.com/store/apps/details?id=...
# 9          1  https://play.google.com/store/apps/details?id=...
#
#                                             iOS_link  \
# 0  https://apps.apple.com/nl/app/villa-pinedo-bud...
# 1                                               None
# 2                                               None
# 3  https://itunes.apple.com/nl/app/care-free/id11...
# 4  https://itunes.apple.com/nl/app/klup-de-social...
# 5  https://itunes.apple.com/us/app/zen-timer-medi...
# 6  https://itunes.apple.com/nl/app/sochicken/id42...
# 7  https://apps.apple.com/nl/app/happify-for-stre...
# 8  https://apps.apple.com/nl/app/fjaere-uitvaartw...
# 9  https://apps.apple.com/nl/app/meditation-momen...
#
#                          Desktop_link
# 0         https://www.villapinedo.nl/
# 1               https://www.oopoeh.nl
# 2   https://soundandhappy.app/nl/home
# 3                                None
# 4                 https://kluppen.nl/
# 5         http://www.insighttimer.com
# 6               https://sochicken.nl/
# 7            https://www.happify.com/
# 8                 https://fjaere.com/
# 9  https://www.meditationmoments.com/
# Data van tabel: evie_data
#    id                                        Titel  \
# 0   1                    VGZ Mindfulness Coach app
# 1   2                            Naasten in Kracht
# 2   3                     SAM (Stress Autism Mate)
# 3   4         Lezing: Laat ons ook ongelukkig zijn
# 4   5                             Gesprekstool UP!
# 5   6                 Je verhaal kwijt via de chat
# 6   7  Psychosegevoelig? Vind hier meer informatie
# 7   8                        Advies of hulp nodig?
# 8   9                   Beter slapen, enkele tips.
# 9  10                 De voordelen van ontspannen.
#
#                                Categorieen  \
# 0                                     Doen
# 1                                     Doen
# 2                                     Doen
# 3                         Luisteren,Kijken
# 4                                     Doen
# 5                                   Praten
# 6  Luisteren,Lezen,Kijken,Ontmoeten,Praten
# 7                                   Praten
# 8                                    Lezen
# 9                                    Lezen
#
#                                                 Link  \
# 0    https://evie.nl/bron/vgz-mindfulness-coach-app/
# 1            https://evie.nl/bron/naasten-in-kracht/
# 2       https://evie.nl/bron/sam-stress-autism-mate/
# 3  https://evie.nl/bron/lezing-laat-ons-ook-ongel...
# 4              https://evie.nl/bron/gesprekstool-up/
# 5  https://evie.nl/bron/je-verhaal-kwijt-via-de-c...
# 6  https://evie.nl/bron/informatie-en-perspectief...
# 7         https://evie.nl/bron/advies-of-hulp-nodig/
# 8     https://evie.nl/bron/beter-slapen-enkele-tips/
# 9  https://evie.nl/bron/de-voordelen-van-ontspannen/
#
#                                       Afbeelding_url  \
# 0  https://evie.nl/wp-content/uploads/2023/01/Bro...
# 1  https://evie.nl/wp-content/uploads/2023/01/dag...
# 2  https://evie.nl/wp-content/uploads/2023/01/Evi...
# 3  https://evie.nl/wp-content/uploads/2023/11/BRO...
# 4  https://evie.nl/wp-content/uploads/2023/01/eli...
# 5  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 6  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 7  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 8  https://evie.nl/wp-content/uploads/2023/01/Bro...
# 9  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
#
#                                         Beschrijving  \
# 0  Wil jij meer rust en ontspanning in je dagelij...
# 1  Naasten in Kracht is er voor naasten van mense...
# 2  SAM is een wetenschappelijk onderbouwde gepers...
# 3  Lezing door psychiater Dirk de Wachter. “We zi...
# 4  UP! is de nieuwe gesprekstool die jongeren en ...
# 5  Ben je op zoek naar advies, of antwoord op je ...
# 6  Via PsychoseNet hebje laagdrempelige toegang t...
# 7  De professionele hulpverleners van MIND Korrel...
# 8  Op de website van Mentaal Vitaal vind je achte...
# 9  Op de website van Mentaal Vitaal vind je achte...
#
#                                  Link_naar_meer_info          Tekst_knop
# 0  https://www.vgz.nl/gezond-leven/mentale-gezond...    Meer over de app
# 1                      https://naasteninkracht.nl/nl         Bekijk bron
# 2                   https://www.stressautismmate.nl/         Bekijk bron
# 3        https://www.youtube.com/watch?v=TX_dsdKNPGU    Bekijk de lezing
# 4           https://app.whappbot.com/chat/up_bodymap         Bekijk bron
# 5       https://www.psychosenet.nl/psychosenet-chat/  Ga naar de website
# 6       https://www.psychosenet.nl/over-psychosenet/  Ga naar de website
# 7                         https://mindkorrelatie.nl/  Ga naar de website
# 8  https://www.mentaalvitaal.nl/problemen-oplosse...           Lees meer
# 9  https://www.mentaalvitaal.nl/mentaal-fit/ontsp...  Ga naar de website
# Data van tabel: thuisarts
#    id                                      Onderwerp  \
# 0   1                                       Aambeien
# 1   2                                       Aambeien
# 2   3                                       Aambeien
# 3   4  Aanvallen van duizeligheid bij of na migraine
# 4   5  Aanvallen van duizeligheid bij of na migraine
# 5   6                                Aangezichtspijn
# 6   7                                Aangezichtspijn
# 7   8                                           Acne
# 8   9                                           Acne
# 9  10                                           Acne
#
#                                       Link_onderwerp  \
# 0                  https://www.thuisarts.nl/aambeien
# 1                  https://www.thuisarts.nl/aambeien
# 2                  https://www.thuisarts.nl/aambeien
# 3  https://www.thuisarts.nl/aanvallen-van-duizeli...
# 4  https://www.thuisarts.nl/aanvallen-van-duizeli...
# 5           https://www.thuisarts.nl/aangezichtspijn
# 6           https://www.thuisarts.nl/aangezichtspijn
# 7                      https://www.thuisarts.nl/acne
# 8                      https://www.thuisarts.nl/acne
# 9                      https://www.thuisarts.nl/acne
#
#                                         Samenvatting  \
# 0  Een aambei is een bobbeltje aan de binnenkant ...
# 1  Een aambei is een bobbeltje aan de binnenkant ...
# 2  Een aambei is een bobbeltje aan de binnenkant ...
# 3  Als u migraine heeft of heeft gehad, kunt u so...
# 4  Als u migraine heeft of heeft gehad, kunt u so...
# 5  Bij aangezichtspijn heeft u heftige pijnaanval...
# 6  Bij aangezichtspijn heeft u heftige pijnaanval...
# 7  Vanaf de puberteit kun je puistjes krijgen. Di...
# 8  Vanaf de puberteit kun je puistjes krijgen. Di...
# 9  Vanaf de puberteit kun je puistjes krijgen. Di...
#
#                                       Situatie_Titel  \
# 0                                    Ik heb aambeien
# 1              Er komt bloed uit mijn anus (poepgat)
# 2                            Ik wil veel vezels eten
# 3  Ik heb aanvallen van duizeligheid en heb of ha...
# 4  Ik ga speciale oefeningen doen tegen duizeligheid
# 5                    Ik heb last van aangezichtspijn
# 6                           Ik heb last van kaakpijn
# 7           Ik heb puistjes (acne). Wat kan ik doen?
# 8    Ik heb acne en krijg medicijnen van de huisarts
# 9                Ik heb acne en ga naar de huid-arts
#
#                                        Situatie_Link
# 0  https://www.thuisarts.nl/aambeien/ik-heb-aambeien
# 1  https://www.thuisarts.nl/bloed-uit-anus/er-kom...
# 2  https://www.thuisarts.nl/verstopping/ik-wil-ve...
# 3  https://www.thuisarts.nl/evenwichts-migraine/i...
# 4  https://www.thuisarts.nl/speciale-oefeningen-t...
# 5  https://www.thuisarts.nl/aangezichtspijn/ik-he...
# 6  https://www.thuisarts.nl/aangezichtspijn/ik-he...
# 7  https://www.thuisarts.nl/acne/ik-heb-puistjes-...
# 8  https://www.thuisarts.nl/acne/ik-heb-acne-en-k...
# 9  https://www.thuisarts.nl/acne/ik-heb-acne-en-g...
# Data van tabel: vierstroom_nieuws
#    id                                              Titel  \
# 0   1  Sterk bewerkt voedsel zou dementie kunnen verg...
# 1   2  Ontdek de beste herfstuitjes via de Vierstroom...
# 2   3    Wat verandert er in 2025 in je zorgverzekering?
# 3   4                      Vier de Dag van de Mantelzorg
# 4   5                               Initiatievenkalender
# 5   6  In gesprek met Gerrie, ledenconsulent en auteu...
# 6   7                  Nieuwe editie Vierstroom Magazine
# 7   8              Heerlijke en voedzame herfstgerechten
# 8   9              Tips om minder eenzaamheid te ervaren
# 9  10                Interview met ritueelbegeleider Bea
#
#                                                 Link  \
# 0  https://www.vierstroom.nl/nieuws/504/sterk-bew...
# 1  https://www.vierstroom.nl/nieuws/570/ontdek-de...
# 2  https://www.vierstroom.nl/nieuws/571/wat-veran...
# 3  https://www.vierstroom.nl/nieuws/564/vier-de-d...
# 4  https://www.vierstroom.nl/nieuws/559/initiatie...
# 5  https://www.vierstroom.nl/nieuws/566/in-gespre...
# 6  https://www.vierstroom.nl/nieuws/495/nieuwe-ed...
# 7  https://www.vierstroom.nl/nieuws/562/heerlijke...
# 8  https://www.vierstroom.nl/nieuws/557/tips-om-m...
# 9  https://www.vierstroom.nl/nieuws/552/interview...
#
#                                            Image_URL  \
# 0  https://www.vierstroom.nl/thumbs/pexels-polina...
# 1  https://www.vierstroom.nl/thumbs/aron-marinell...
# 2  https://www.vierstroom.nl/thumbs/zorgverzekeri...
# 3  https://www.vierstroom.nl/thumbs/ballonnen-22-...
# 4  https://www.vierstroom.nl/thumbs/old-people-wa...
# 5  https://www.vierstroom.nl/thumbs/er5-6776-bewe...
# 6  https://www.vierstroom.nl/thumbs/cover-vm3-202...
# 7  https://www.vierstroom.nl/thumbs/pompoen-uitge...
# 8  https://www.vierstroom.nl/thumbs/frame-2-f1116...
# 9  https://www.vierstroom.nl/thumbs/content-pixie...
#
#                                    Beschrijving_kort  \
# 0  Dat sterk bewerkte voedsel niet goed is voor o...
# 1  Lekker naar buiten gaan is goed voor je lichaa...
# 2  In 2025 komen er belangrijke veranderingen in ...
# 3  Ben je mantelzorger in de gemeente Capelle? Op...
# 4  In het hele land worden activiteiten georganis...
# 5  Dit boek is een waardevolle gids voor iedereen...
# 6  ‘Eenzaamheid is voor mij niet het gebrek aan m...
# 7  In de herfst hebben veel mensen behoefte aan i...
# 8  In dit artikel geven we tips voor nieuwe hobby...
# 9  Als ritueelbegeleider helpt Bea van de Hoef fa...
#
#                                    Beschrijving_lang              Categorie
# 0  Dat sterk bewerkte voedsel niet goed is voor o...       Gezonde hersenen
# 1  Eropuit gaan is belangrijk voor lichaam en gee...                Eropuit
# 2  In 2025 komen er belangrijke veranderingen in ...                Wegwijs
# 3  Vier samen de Dag van de Mantelzorg  Ben je ma...             Mantelzorg
# 4  De Week tegen Eenzaamheid is een belangrijke w...  Eén tegen eenzaamheid
# 5  Mantelzorg speelt een steeds grotere rol in on...             Mantelzorg
# 6  Vierstroom Magazine is een magazine boordevol ...    Vierstroom Magazine
# 7  In de herfst krijgen veel mensen de behoefte a...               Recepten
# 8  Heb je het gevoel dat je sociale leven wat mee...  Eén tegen eenzaamheid
# 9  Als ritueelbegeleider helpt Bea van de Hoef fa...    Vierstroom Magazine
# Data van tabel: workshops_zve
#    id                                 titel          organisatie  \
# 0   1                Training Goed Besturen  Gemeente Zoetermeer
# 1   2  Training Fondsenwerving I Fonds 1818  Gemeente Zoetermeer
# 2   3     Introductie persbericht schrijven  Gemeente Zoetermeer
#
#                                    beschrijving_kort  \
# 0                                               Wat?
# 1  Ben je met jouw stichting of vereniging actief...
# 2  Heb je relevant of actueel nieuws? Dan kun je ...
#
#                                    beschrijving_lang             datum  \
# 0  Wat? Als bestuurder komt er nogal wat op je af...  Start 28-01-2025
# 1  Ben je met jouw stichting of vereniging actief...        18-02-2025
# 2  Heb je relevant of actueel nieuws? Dan kun je ...        11-03-2025
#
#                                            image_url  \
# 0  https://www.zoetermeervoorelkaar.nl/uploads/ca...
# 1  https://www.zoetermeervoorelkaar.nl/uploads/ca...
# 2  https://www.zoetermeervoorelkaar.nl/uploads/ca...
#
#                                        link_workshop  aantal_bijeenkomsten  \
# 0  https://www.zoetermeervoorelkaar.nl/cursusaanb...                     2
# 1  https://www.zoetermeervoorelkaar.nl/cursusaanb...                     1
# 2  https://www.zoetermeervoorelkaar.nl/cursusaanb...                     1
#
#        eerste_bijeenkomst     laatste_bijeenkomst     inschrijven_kan_tot  \
# 0  28-01-2025 - 19:30 uur  04-03-2025 - 19:30 uur  27-01-2025 - 23:55 uur
# 1                    None                    None  14-02-2025 - 23:59 uur
# 2                    None                    None                    None
#
#         datum_bijeenkomst
# 0                    None
# 1  18-02-2025 - 14:00 uur
# 2  11-03-2025 - 19:00 uur

# %%
df_IZ["Afbeelding_url"][1]
# Out:
# "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20624%20312'%3E%3C/svg%3E"
