# %% [markdown]
# <div style="background-color:	#103060; text-align:center; vertical-align: middle; padding:40px 0; margin-top:30px">
# <h1 style="color:white">Database SamenZoeterMeerGezond</h1>
# <b style="color:white">Rogier Gernaat</b>
#     </div>
#
# <a name='start'></a>

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Inladen van de library's</strong>
# </div>

# %%
# !pip install mysql-connector-python
# pip install mysql
# !pip install pandas
# !pip install python-dotenv

# %%
import pandas as pd
import warnings
import mysql.connector
import os
from dotenv import load_dotenv

# Onderdruk de UserWarning
warnings.simplefilter("ignore", UserWarning)

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Server Variabelen met .env</strong>
# </div>

# %%
load_dotenv()
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT', 3306)
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_name = os.getenv('DB_NAME')
db_ssl_ca = os.getenv('DB_SSL_CA')

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken Databases</strong>
# </div>

# %%
# Connect to the database
conn = mysql.connector.connect(
    host=db_host,
    port=db_port,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

#Query the database
query = "SHOW Databases"
databases = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the data  
databases
# Out:
#              Database
# 0  information_schema
# 1               mysql
# 2  performance_schema
# 3    scraping_project
# 4                 sys

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken Tabellen</strong>
# </div>

# %%
# Connect to the database
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

#Query the database
query = "SHOW Tables"
tables = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the data
tables
# Out:
#     Tables_in_scraping_project
# 0                 activiteiten
# 1           activiteiten_nlzve
# 2   activiteiten_scheidingpunt
# 3             activiteiten_uit
# 4             activiteiten_zma
# 5             activiteiten_zte
# 6                     apps_ggd
# 7                    evie_data
# 8                    thuisarts
# 9            vierstroom_nieuws
# 10               workshops_zve

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Bekijken website</strong>
# </div>
# Vanaf hier kun je alle websites bekijken, tabel aanpassen kan uiteraard via de query

# %%
# Establish the connection to Azure MySQL
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

query = "SELECT * FROM evie_data"
df_IZ = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display a sample of the data
df_IZ.head()
# Out:
#    id                                              Titel     Categorieen  \
# 0   1                Wat je moet weten over drugsgebruik           Lezen
# 1   2  Welke rol speelt alcohol bij andere mensen in ...       Luisteren
# 2   3                          VGZ Mindfulness Coach app            Doen
# 3   4             Vind je buddy en stop samen met roken!       Ontmoeten
# 4   5                             Zoek de verbinding op!  Doen,Ontmoeten
#
#                                                 Link  \
# 0  https://evie.nl/bron/wat-je-moet-weten-over-dr...
# 1  https://evie.nl/bron/welke-rol-speelt-alcohol-...
# 2    https://evie.nl/bron/vgz-mindfulness-coach-app/
# 3  https://evie.nl/bron/vind-je-buddy-en-stop-sam...
# 4        https://evie.nl/bron/zoek-de-verbinding-op/
#
#                                       Afbeelding_url  \
# 0  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 1  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 2  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 3  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
# 4  'http://www.w3.org/2000/svg'%20viewBox='0%200%...
#
#                                         Beschrijving  \
# 0  Wat zijn drugs? Hoe kan ik omgaan met drugs of...
# 1  In de podcast ‘Eerlijk over alcohol’ praat pre...
# 2  Wil jij meer rust en ontspanning in je dagelij...
# 3  Wil jij stoppen met roken, maar geen bemoeieni...
# 4  Op het platform van “Who is there?” word je al...
#
#                                  Link_naar_meer_info          Tekst_knop
# 0                          https://www.drugsinfo.nl/  Ga naar de website
# 1  https://open.spotify.com/show/7eqnsgjPlonxGUf2...  Luister de podcast
# 2  https://www.vgz.nl/gezond-leven/mentale-gezond...    Meer over de app
# 3                             https://www.quiddy.nl/     Download de app
# 4                       https://www.who-is-there.nl/             Doe mee

# %% [markdown]
# <div style="background-color:#006069; color:white; padding: 10px;">
#     <strong>Loop voor het snel bekijken van alle tabellen achter elkaar</strong>
# </div>

# %%
# Establish the connection to Azure MySQL
conn = mysql.connector.connect(
    host=db_host,
    user=db_user,
    password=db_password,
    database=db_name,
    ssl_ca=db_ssl_ca  
)

# Haal alle tabellen op
show_tables_query = "SHOW TABLES"
tables_df = pd.read_sql(show_tables_query, conn)

# Loop door alle tabellen en haal gegevens op
for table in tables_df.iloc[:, 0]:
    query = f"SELECT * FROM {table}"
    df = pd.read_sql(query, conn)
    
    # Toon een voorbeeld van de gegevens per tabel
    print(f"Data van tabel: {table}")
    display(df.head(10))  # Eerste 10 rijen kan aanpassen naar een ander getal
    print("\n")

# connectie uitzettenm
conn.close()
# Out:
# Data van tabel: activiteiten
#    id                                            Titel  \
# 0   1               Informatiebijeenkomst huisvesting
# 1   2          Training assertiviteit voor volwassenen
# 2   3  Ouderbijeenkomst over kinderen en schermgebruik
#
#                                                 Link Datum_numeriek  \
# 0  https://www.inzet-indewijk.nl/informatiebijeen...     2025-01-07
# 1  https://www.inzet-indewijk.nl/training-asserti...     2025-04-07
# 2  https://www.inzet-indewijk.nl/ouderbijeenkomst...     2025-01-08
#
#                  Datum_text  \
# 0   dinsdag, 7 januari 2025
# 1     maandag, 7 april 2025
# 2  woensdag, 8 januari 2025
#
#                                         Beschrijving       Starttijd  \
# 0                 Stel al je vragen over huisvesting 0 days 10:00:00
# 1                           Leer voor jezelf opkomen 0 days 18:30:00
# 2  in samenwerking met de mediaconsulent van Bibl... 0 days 09:30:00
#
#          Eindtijd                                       Locatie  \
# 0 0 days 11:30:00  inZet Buytenwegh & De Leyens, Teldersrode 25
# 1 0 days 21:00:00  inZet Buytenwegh & De Leyens, Teldersrode 25
# 2 0 days 11:30:00             Forum Zoetermeer, Stadhuisplein 1
#
#                                       URL_afbeelding  \
# 0  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 1  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
# 2  https://cuatro.sim-cdn.nl/inzetindewijk/upload...
#
#                                   Extra_beschrijving
# 0  Heb jij vragen over huisvesting? Kom dan naar ...
# 1  Durf je niet te zeggen wat je werkelijk vindt?...
# 2  Bibliotheek Zoetermeer en inZet organiseren sa...
# Data van tabel: activiteiten_nlzve
#                            Titel  \
# 0  Meet up Het Dagelijks Bestaan
# 1                    Atelier VZC
# 2   Webinar over voorzorgcirkels
# 3                    Atelier VZC
# 4                    Atelier VZC
# 5   Lunchwebinar Voorzorgcirkels
# 6   Lunchwebinar Voorzorgcirkels
#
#                                              Locatie            Begintijd  \
# 0  Het Dagelijks Bestaan Weg naar Vierakker 47 72...  30-01-2025 om 10:30
# 1                                             Online  21-01-2025 om 13:30
# 2                                             Online  18-02-2025 om 12:00
# 3                                                     18-03-2025 om 13:30
# 4                                             Online  13-05-2025 om 13:30
# 5                                             Online  08-04-2025 om 12:00
# 6                                             Online  10-06-2025 om 12:00
#
#               Eindtijd                                  Beschrijving_kort  \
# 0  30-01-2025 om 15:00  Het Dagelijks Bestaan is een leer- werk- en wo...
# 1  21-01-2025 om 15:30  Heb jij gehoord van voorzorgcirkels, ben je ni...
# 2  18-02-2025 om 13:00  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 3  18-03-2025 om 15:30  Praktijktraining: Hoe start je een voorzorgcir...
# 4  13-05-2025 om 15:30  Praktijktraining: Hoe start je een voorzorgcir...
# 5  08-04-2025 om 13:00  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 6  10-06-2025 om 13:00  Maak kennis met voorzorgcirkel-pioniers en lee...
#
#                                    Beschrijving_lang  \
# 0  Het Dagelijks Bestaan is een leer- werk- en wo...
# 1  Heb jij gehoord van voorzorgcirkels, ben je ni...
# 2  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 3  Praktijktraining: Hoe start je een voorzorgcir...
# 4  Praktijktraining: Hoe start je een voorzorgcir...
# 5  Benieuwd wat voorzorgcirkels precies zijn, waa...
# 6  Maak kennis met voorzorgcirkel-pioniers en lee...
#
#                                                 Link  \
# 0  https://www.nlzve.nl/agenda/2778436.aspx?t=Mee...
# 1  https://www.nlzve.nl/agenda/2875128.aspx?t=Ate...
# 2  https://www.nlzve.nl/agenda/2875129.aspx?t=Web...
# 3  https://www.nlzve.nl/agenda/2955210.aspx?t=Ate...
# 4  https://www.nlzve.nl/agenda/2955212.aspx?t=Ate...
# 5  https://www.nlzve.nl/agenda/2955215.aspx?t=Lun...
# 6  https://www.nlzve.nl/agenda/2955216.aspx?t=Lun...
#
#                                       Afbeelding_url
# 0  https://www.nlzve.nl/media/sectionimages/a3318...
# 1  https://www.nlzve.nl/media/sectionimages/a3318...
# 2  https://www.nlzve.nl/media/sectionimages/a3318...
# 3  https://www.nlzve.nl/media/sectionimages/a3318...
# 4  https://www.nlzve.nl/media/sectionimages/a3318...
# 5  https://www.nlzve.nl/media/sectionimages/a3318...
# 6  https://www.nlzve.nl/media/sectionimages/a3318...
# Data van tabel: activiteiten_scheidingpunt
#    id                                            titel  \
# 0   1                              Stoere Schildpadden
# 1   2                                   Dappere Dino’s
# 2   3                 KIESgroep voor Primair Onderwijs
# 3   4                   KIESgroep Voortgezet Onderwijs
# 4   5                                     Villa Pinedo
# 5   6     Informatiebijeenkomst voor gescheiden ouders
# 6   7              Online ouderschapscursus Ouders Inc
# 7   8           Online ouderbijeenkomst over scheiding
# 8   9  Houd me Vast: voor stellen met relatieproblemen
# 9  10               Contactgroep voor Verstoten ouders
#
#                                                 link  \
# 0  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 1  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 2  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 3  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 4  https://www.scheidingspunt.nl/agenda-jeugd/ite...
# 5  https://www.scheidingspunt.nl/agenda-volwassen...
# 6  https://www.scheidingspunt.nl/agenda-volwassen...
# 7  https://www.scheidingspunt.nl/agenda-volwassen...
# 8  https://www.scheidingspunt.nl/agenda-volwassen...
# 9  https://www.scheidingspunt.nl/agenda-volwassen...
#
#                                                  wat  \
# 0                                    Groepstraining.
# 1                                    Groepstraining.
# 2                   Spel- en lotgenotencontactgroep.
# 3                  Doe- en praatgroep voor jongeren.
# 4              Online buddyproject en ondersteuning.
# 5     Informatiebijeenkomsten voor gescheiden ouders
# 6  Online programma dat (aanstaande) ouders helpt...
# 7  Een online bijeenkomst over hoe kinderen en sc...
# 8  Groepstraining voor stellen om de relatie te v...
# 9                Contactgroep voor verstoten ouders.
#
#                                             voor_wie  \
# 0  Kinderen van 4 tot 6 jaar waarvan de ouders ga...
# 1  Kinderen van 6 tot 8 jaar waarvan de ouders ga...
# 2  Kinderen van 8 t/m 12 jaar waarvan de ouders g...
# 3  Kinderen uit klas 1 t/m 3 waarvan de ouders ga...
# 4  Kinderen 10 – 23 jaar waarvan ouders gaan sche...
# 5  Voor ouders die voor, tijdens of na de scheidi...
# 6  Voor zwangeren en ouders met kinderen van 0-4 ...
# 7  Voor alle gescheiden ouders, professionals en ...
# 8         Voor stellen die relatieproblemen ervaren.
# 9  Voor ouders die hun kind(eren) niet meer, of h...
#
#                                              wanneer
# 0      Voorjaar 2025, start woensdagmiddag 19 maart.
# 1      Voorjaar 2025, start woensdagmiddag 19 maart.
# 2            Start donderdagmiddag 20 februari 2025.
# 3                  Start bij voldoende aanmeldingen!
# 4                        Gehele jaar, naar behoefte.
# 5     Iedere 3e woensdag in de maand en de week erna
# 6  In eigen tempo, thuis op de bank wanneer julli...
# 7                          Vrijdag 13 december 2024.
# 8  Bij aanmelding van min. 4 stellen start HMV z....
# 9  Iedere eerste woensdagavond van de maand met u...
# Data van tabel: activiteiten_uit
#    id                                              Titel  \
# 0   1                               Anastasia de musical
# 1   2                               Rico's Kerstvakantie
# 2   3                   Top 2000 Live - 25 jaar Top 2000
# 3   4                             Latin Improv Jam-night
# 4   5  BachaSalsa met Liveband Bachata Con Clase Kers...
# 5   6                            Hitmachine NYE festival
# 6   7                        Lasershows met oud en nieuw
# 7   8          Proeflessen Salsa en Bachata januari 2025
# 8   9    Nieuwjaarsvoorstelling - Nieuwjaarsvoorstelling
# 9  10             Carine Crutzen en Bert Luppes - HULDE!
#
#                                         Beschrijving  \
# 0  Deze kerstvakantie brengt Greg & Baud Producti...
# 1  Deze kerstvakantie wordt SilverDome omgetoverd...
# 2  Wat begon als een lijstjesfeestje bij Radio2, ...
# 3  Het is zover! Zoetermeer bruist nu echt. Sinds...
# 4  De eerste editie was een groot succes en vol g...
# 5  Zin in een feestje met oud en nieuw? En ben je...
# 6  Dit jaar laten we de lucht in Zoetermeer stral...
# 7  Goede voornemens voor het nieuwe jaar? Ga je m...
# 8  Op dinsdag 7 januari 2025 luidt gemeente Zoete...
# 9  Geesje en Adam vieren hun zeventigjarig huweli...
#
#                                                Datum     Starttijd   Eindtijd  \
# 0                       Dagelijks t/m 5 januari 2025         20.00  17.00 uur
# 1                           Vrijdag 27 december 2024         11.00  13.45 uur
# 2                            Woensdag 8 januari 2025  om 20.00 uur       None
# 3                Elke donderdag t/m 31 december 2024         21.00  23.59 uur
# 4                          Zaterdag 28 december 2024  om 21.00 uur       None
# 5                           Dinsdag 31 december 2024         00.30  06.00 uur
# 6                           Dinsdag 31 december 2024         19.00  19.45 uur
# 7  Dagelijks vanaf 6 januari 2025 t/m 10 januari ...         19.15  20.00 uur
# 8                             Dinsdag 7 januari 2025         20.15  21.30 uur
# 9                           Donderdag 9 januari 2025  om 20.00 uur       None
#
#      Prijs                  Straat            Postcode  \
# 0  € 17,50        Paletsingel 39 c   2718NT Zoetermeer
# 1   € 7,95  Van der Hagenstraat 20  2722 NT Zoetermeer
# 2     None         Theaterplein 10  2711 EK Zoetermeer
# 3   Gratis       Dorpsstraat 114 A   2712AN Zoetermeer
# 4  € 15,00       Dorpsstraat 114 A   2712AN Zoetermeer
# 5  € 17,99  Van der Hagenstraat 20  2722 NT Zoetermeer
# 6   Gratis              Zoetermeer                None
# 7   € 5,00     Stadhoudersring 392   2713GN Zoetermeer
# 8     None         Theaterplein 10  2711 EK Zoetermeer
# 9     None         Theaterplein 10  2711 EK Zoetermeer
#
#                            Naam                         Email  \
# 0  Picasso Lyceum - Theaterzaal        anastasia@greg-baud.nl
# 1                    Silverdome            info@silverdome.nl
# 2                                servicebalie@stadstheater.nl
# 3                   Le Club BBQ             info@leclubbbq.nl
# 4                   Le Club BBQ             info@leclubbbq.nl
# 5                                                        None
# 6                         Markt                          None
# 7       Salsaventura Zoetermeer    zoetermeer@salsaventura.nl
# 8                                servicebalie@stadstheater.nl
# 9                                servicebalie@stadstheater.nl
#
#                          Bedrijf_Website  \
# 0                http://www.greg-baud.nl
# 1                 https://silverdome.nl/
# 2                https://stadstheater.nl
# 3                http://www.leclubbbq.nl
# 4                http://www.leclubbbq.nl
# 5          https://www.hitmachinexxl.nl/
# 6                                   None
# 7  http://www.salsaventura.nl/lesrooster
# 8                https://stadstheater.nl
# 9                https://stadstheater.nl
#
#                                          Url_plaatje
# 0  https://assets.plaece.nl/thumb/LcJAWB2gqqDzyrc...
# 1  https://assets.plaece.nl/thumb/S--6YjFULMWQIXe...
# 2  https://assets.plaece.nl/thumb/M9vwcu4jaoKEbjQ...
# 3  https://assets.plaece.nl/thumb/SZRTLfKnaceqoSb...
# 4  https://assets.plaece.nl/thumb/iXB8OcpEaG-kwds...
# 5  https://assets.plaece.nl/thumb/yT3_Z_ktIgWmM50...
# 6  https://assets.plaece.nl/thumb/wSDVbpWX3eOMkAG...
# 7  https://assets.plaece.nl/thumb/ZDxvYC8qqUlbiX4...
# 8  https://assets.plaece.nl/thumb/xwlPyhpW27HLg3R...
# 9  https://assets.plaece.nl/thumb/KKaoyCGxsEG5ewC...
# Data van tabel: activiteiten_zma
#    id                                              Titel  \
# 0   1                    Beauty and the Beast in het CKC
# 1   2  Carillonconcert Geuzenliederen van Adriaen Val...
# 2   3                         Thin Lizzard Remember Phil
# 3   4                       Rico’s kerstvakantie ijspret
# 4   5                       Nieuwjaarsduik 5 t/m 12 jaar
# 5   6      Winterpret op Speelboerderij Het Buitenbeest
# 6   7      Winterpret op Speelboerderij Het Buitenbeest
# 7   8  Nieuwjaarsdiner bij Speelboerderij Het Buitenb...
# 8   9                       Rico’s kerstvakantie ijspret
# 9  10      Winterpret op Speelboerderij Het Buitenbeest
#
#                                                 Link  \
# 0  https://zoetermeeractief.nl/agenda/complete-ag...
# 1  https://zoetermeeractief.nl/agenda/complete-ag...
# 2  https://zoetermeeractief.nl/agenda/complete-ag...
# 3  https://zoetermeeractief.nl/agenda/complete-ag...
# 4  https://zoetermeeractief.nl/agenda/complete-ag...
# 5  https://zoetermeeractief.nl/agenda/complete-ag...
# 6  https://zoetermeeractief.nl/agenda/complete-ag...
# 7  https://zoetermeeractief.nl/agenda/complete-ag...
# 8  https://zoetermeeractief.nl/agenda/complete-ag...
# 9  https://zoetermeeractief.nl/agenda/complete-ag...
#
#                                         Beschrijving              Startdatum  \
# 0  Deze kerstvakantie wordt een sprookje, Storyte...  januari 04, 2025 20:00
# 1  De komende bespelingen zullen in teken staan v...  januari 04, 2025 12:00
# 2  Thin Lizzard is een Thin Lizzy Tributeband. 5 ...  januari 03, 2025 20:30
# 3  Deze kerstvakantie wordt SilverDome omgetoverd...  januari 03, 2025 11:00
# 4  De nieuwjaarsduik is een hele (k)oude traditie...  januari 02, 2025 15:00
# 5  Kom je in de kerstvakantie ook koekjes bakken,...                    None
# 6  Kom je in de kerstvakantie ook koekjes bakken,...                    None
# 7  Om 2025 feestelijk met elkaar te starten organ...  januari 03, 2025 18:00
# 8  Deze kerstvakantie wordt SilverDome omgetoverd...  januari 02, 2025 11:00
# 9  Kom je in de kerstvakantie ook koekjes bakken,...                    None
#
#                                Url_header_afbeelding  \
# 0  https://zoetermeeractief.nl/images/images/even...
# 1  https://zoetermeeractief.nl/images/imagesevent...
# 2  https://zoetermeeractief.nl/images/imagesevent...
# 3  https://zoetermeeractief.nl/images/images/even...
# 4  https://zoetermeeractief.nl/images/images/even...
# 5  https://zoetermeeractief.nl/images/images/even...
# 6  https://zoetermeeractief.nl/images/images/even...
# 7  https://zoetermeeractief.nl/images/images/even...
# 8  https://zoetermeeractief.nl/images/images/even...
# 9  https://zoetermeeractief.nl/images/images/even...
#
#                                   Extra_beschrijving  \
# 0  Deze kerstvakantie wordt een sprookje, Storyte...
# 1  De komende bespelingen zullen in teken staan v...
# 2  Thin Lizzard is een Thin Lizzy Tributeband. 5 ...
# 3  Deze kerstvakantie wordt SilverDome omgetoverd...
# 4  De nieuwjaarsduik is een hele (k)oude traditie...
# 5  Kom je in de kerstvakantie ook koekjes bakken,...
# 6  Kom je in de kerstvakantie ook koekjes bakken,...
# 7  Om 2025 feestelijk met elkaar te starten organ...
# 8  Deze kerstvakantie wordt SilverDome omgetoverd...
# 9  Kom je in de kerstvakantie ook koekjes bakken,...
#
#                                       Url_afbeelding       Categorie_1  \
# 0  https://zoetermeeractief.nl/images/Zoetermeern...      Activiteiten
# 1                                               None            Muziek
# 2                                               None            Muziek
# 3  https://zoetermeeractief.nl/images/Zoetermeern...      Activiteiten
# 4                                               None  Sportevenementen
# 5                                               None      Activiteiten
# 6                                               None      Activiteiten
# 7                                               None      Activiteiten
# 8  https://zoetermeeractief.nl/images/Zoetermeern...      Activiteiten
# 9                                               None      Activiteiten
#
#                 Categorie_2     Categorie_3       Categorie_4
# 0                      Dorp         Theater  Theater alg logo
# 1  Oude Kerk Concerten logo            None              None
# 2         De Boerderij logo            None              None
# 3                Palenstein           Jeugd       Jeugd  logo
# 4                Sport logo        Vakantie              None
# 5                Kerst logo        Vakantie             Kerst
# 6                Kerst logo        Vakantie             Kerst
# 7                  Vakantie  Speelmeer logo              None
# 8                Palenstein           Jeugd       Jeugd  logo
# 9                Kerst logo        Vakantie             Kerst
# Data van tabel: activiteiten_zte
#    id                                              Titel  \
# 0   1         Welke straat is de liefste van Zoetermeer?
# 1   2  Interview: Karaokeavond voor Hindoestaanse gem...
# 2   3            Community aan het woord: Love Your Mind
# 3   4              Terugblik Week tegen Eenzaamheid 2024
# 4   5               Community aan het woord: Gil Lieveld
# 5   6       Community aan het woord: Sociale sportschool
# 6   7                     Activiteit: Summer Sing Alongs
# 7   8  Samen wandelen in het groen zorgt voor verbind...
# 8   9  Netwerkbijeenkomst: Eten en Ontmoeten in Buyte...
# 9  10            Community aan het woord: Interesse café
#
#                                                 Link  \
# 0  https://zoetermeertegeneenzaamheid.nl/nieuws/l...
# 1  https://zoetermeertegeneenzaamheid.nl/nieuws/i...
# 2  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 3  https://zoetermeertegeneenzaamheid.nl/nieuws/w...
# 4  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 5  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
# 6  https://zoetermeertegeneenzaamheid.nl/nieuws/a...
# 7  https://zoetermeertegeneenzaamheid.nl/nieuws/s...
# 8  https://zoetermeertegeneenzaamheid.nl/nieuws/n...
# 9  https://zoetermeertegeneenzaamheid.nl/nieuws/c...
#
#                                Url_header_afbeelding Datum_numeriek  \
# 0  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-20
# 1  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-07-15
# 2  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-14
# 3  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-10-10
# 4  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-11-04
# 5  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-08-26
# 6  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-07-29
# 7  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-06-17
# 8  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-06-17
# 9  https://zoetermeertegeneenzaamheid.nl/media/fi...     2024-04-23
#
#                    Datum_text  \
# 0   woensdag 20 november 2024
# 1        maandag 15 juli 2024
# 2  donderdag 14 november 2024
# 3   donderdag 10 oktober 2024
# 4     maandag 4 november 2024
# 5    maandag 26 augustus 2024
# 6        maandag 29 juli 2024
# 7        maandag 17 juni 2024
# 8        maandag 17 juni 2024
# 9       dinsdag 23 april 2024
#
#                                       Url_afbeelding  \
# 0  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 1  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 2  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 3  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 4  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 5  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 6  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 7  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 8  https://zoetermeertegeneenzaamheid.nl/media/fi...
# 9  https://zoetermeertegeneenzaamheid.nl/media/fi...
#
#                                         Beschrijving
# 0  Lief en Leed Zoetermeer startte in 2020 met de...
# 1  Tijdens de karaokeavond kun je genieten van ou...
# 2  Wij zijn Radha Nanhoe en Steven van der Knaap....
# 3  De Zoetermeerse Community tegen Eenzaamheid or...
# 4  Mijn naam is Gil Lieveld en ik ben een onderne...
# 5  De Sociale Sportschool brengt senioren en jong...
# 6  De zomer is niet voor iedereen een leuke tijd,...
# 7  Samen wandelen is gezelliger dan alleen! Daaro...
# 8  Gado gado, gevulde wijnbladeren, pindasaus, ri...
# 9  Het Interessecafé Doe je graag dingen die jouw...
# Data van tabel: apps_ggd
#    id                   App_naam  App_rating  \
# 0   1               Villa Pinedo         5.0
# 1   2            Klup Social app         4.5
# 2   3                     OOPOEH         5.0
# 3   4              Sound & Happy         5.0
# 4   5  Insight Timer - Meditatie         4.5
# 5   6                    Happify         4.5
# 6   7                     Fjaere         4.0
# 7   8                  Care-Free         5.0
# 8   9         Meditation Moments         4.5
# 9  10                  soChicken         4.0
#
#                                    Beschrijving_kort  \
# 0  Villa Pinedo is een app voor kinderen met gesc...
# 1  Klup is een sociale app voor 50-plussers. Op e...
# 2  Met behulp van de informatie, die de website w...
# 3  Met behulp van deze site kan je een kort muzie...
# 4  Insight Timer is een meditatie en mindfulness-...
# 5  Happify is een Engelstalige app die je door da...
# 6  In deze app kan je al je uitvaartwensen en geg...
# 7  Een app over kindermishandeling en hoe kindere...
# 8  Meditation Moments is een Nederlandstalige app...
# 9  soChicken kan je helpen met een gelukkig en ge...
#
#                                    Beschrijving_lang  Dagelijks_Functioneren  \
# 0  Villa Pinedo is de plek waar kinderen met gesc...                       0
# 1  Klup is een sociale app voor 50-plussers die o...                       0
# 2  Stichting OOPOEH – Opa's en Oma's Passen Op Ee...                       0
# 3  Op een makkelijke manier kan je overal wanneer...                       0
# 4  Inzicht Timer biedt je geleide meditaties, lez...                       0
# 5  In de app Happify kiest de gebruiker persoonli...                       0
# 6  Fjaere zorgt ervoor dat alle persoonlijke wens...                       0
# 7  Care-Free is een app over kindermishandeling v...                       1
# 8  De app is opgebouwd rondom momenten op een dag...                       1
# 9  In de app staan interessante artikelen met han...                       1
#
#    Kwaliteit_van_Leven  Lichaamsfuncties  Meedoen  Mentaal_Welbevinden  \
# 0                    0                 0        0                    1
# 1                    1                 0        1                    0
# 2                    0                 1        1                    0
# 3                    1                 0        0                    1
# 4                    0                 0        0                    1
# 5                    1                 0        0                    1
# 6                    1                 0        0                    1
# 7                    1                 1        1                    1
# 8                    1                 1        0                    1
# 9                    1                 0        0                    0
#
#    Zingeving                                       Android_link  \
# 0          1  https://play.google.com/store/apps/details?id=...
# 1          1  https://play.google.com/store/apps/details?id=...
# 2          1                                               None
# 3          1                                               None
# 4          1  https://play.google.com/store/apps/details?id=...
# 5          1  https://play.google.com/store/apps/details?id=...
# 6          1  https://play.google.com/store/apps/details?id=...
# 7          1  https://play.google.com/store/apps/details?id=...
# 8          1  https://play.google.com/store/apps/details?id=...
# 9          1  https://play.google.com/store/apps/details?id=...
#
#                                             iOS_link  \
# 0  https://apps.apple.com/nl/app/villa-pinedo-bud...
# 1  https://itunes.apple.com/nl/app/klup-de-social...
# 2                                               None
# 3                                               None
# 4  https://itunes.apple.com/us/app/zen-timer-medi...
# 5  https://apps.apple.com/nl/app/happify-for-stre...
# 6  https://apps.apple.com/nl/app/fjaere-uitvaartw...
# 7  https://itunes.apple.com/nl/app/care-free/id11...
# 8  https://apps.apple.com/nl/app/meditation-momen...
# 9  https://itunes.apple.com/nl/app/sochicken/id42...
#
#                          Desktop_link
# 0         https://www.villapinedo.nl/
# 1                 https://kluppen.nl/
# 2               https://www.oopoeh.nl
# 3   https://soundandhappy.app/nl/home
# 4         http://www.insighttimer.com
# 5            https://www.happify.com/
# 6                 https://fjaere.com/
# 7                                None
# 8  https://www.meditationmoments.com/
# 9               https://sochicken.nl/
# Data van tabel: evie_data
#    id                                              Titel     Categorieen  \
# 0   1  Welke rol speelt alcohol bij andere mensen in ...       Luisteren
# 1   2                          Test je kennis over drugs            Doen
# 2   3                             Zoek de verbinding op!  Doen,Ontmoeten
# 3   4                Wat je moet weten over drugsgebruik           Lezen
# 4   5                                   Angsten, wat nu?           Lezen
# 5   6       Je alcoholgebruik tijdelijk op pauze zetten?            Doen
# 6   7  Verslaafd aan jou: interactieve video over alc...          Kijken
# 7   8                                 Ik wil gezond eten           Lezen
# 8   9                          VGZ Mindfulness Coach app            Doen
# 9  10         Neem even een moment om goed te ontspannen       Luisteren
#
#                                                 Link  \
# 0  https://evie.nl/bron/welke-rol-speelt-alcohol-...
# 1    https://evie.nl/bron/test-je-kennis-over-drugs/
# 2        https://evie.nl/bron/zoek-de-verbinding-op/
# 3  https://evie.nl/bron/wat-je-moet-weten-over-dr...
# 4               https://evie.nl/bron/angsten-wat-nu/
# 5  https://evie.nl/bron/je-alcoholgebruik-tijdeli...
# 6  https://evie.nl/bron/verslaafd-aan-jou-interac...
# 7           https://evie.nl/bron/ik-wil-gezond-eten/
# 8    https://evie.nl/bron/vgz-mindfulness-coach-app/
# 9  https://evie.nl/bron/neem-even-een-moment-om-g...
#
#                                       Afbeelding_url  \
# 0  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 1  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 2  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 3  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 4  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 5  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 6  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 7  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 8  data:image/svg+xml,%3Csvg%20xmlns='http://www....
# 9  data:image/svg+xml,%3Csvg%20xmlns='http://www....
#
#                                         Beschrijving  \
# 0  In de podcast ‘Eerlijk over alcohol’ praat pre...
# 1  Hoeveel weet jij over drugs? Test hier je kenn...
# 2  Op het platform van “Who is there?” word je al...
# 3  Wat zijn drugs? Hoe kan ik omgaan met drugs of...
# 4  Op Thuisarts.nl lees je wat een angststoornis ...
# 5  Een maand geen alcohol drinken. Durf jij de ui...
# 6  De film ‘Verslaafd aan Jou’ vertelt het verhaa...
# 7  Op Thuisarts.nl lees je meer informatie over g...
# 8  Wil jij meer rust en ontspanning in je dagelij...
# 9  In de podcast serie ‘Brein in balans’ laat de ...
#
#                                  Link_naar_meer_info          Tekst_knop
# 0  https://open.spotify.com/show/7eqnsgjPlonxGUf2...  Luister de podcast
# 1          https://www.drugsenuitgaan.nl/test-jezelf         Test jezelf
# 2                       https://www.who-is-there.nl/             Doe mee
# 3                          https://www.drugsinfo.nl/  Ga naar de website
# 4             https://www.thuisarts.nl/angststoornis  Ga naar de website
# 5                                  https://ikpas.nl/  Ga naar de website
# 6                    https://www.verslaafdaanjou.nl/       Kijk de video
# 7  https://www.thuisarts.nl/gezond-eten/ik-wil-ge...  Ga naar de website
# 8  https://www.vgz.nl/gezond-leven/mentale-gezond...    Meer over de app
# 9  https://open.spotify.com/episode/13nE0AgiX11cJ...  Luister de podcast
# Data van tabel: thuisarts
#    id Onderwerp                     Link_onderwerp  \
# 0   1  Aambeien  https://www.thuisarts.nl/aambeien
# 1   2  Aambeien  https://www.thuisarts.nl/aambeien
# 2   3  Aambeien  https://www.thuisarts.nl/aambeien
# 3   4      ADHD      https://www.thuisarts.nl/adhd
# 4   5      ADHD      https://www.thuisarts.nl/adhd
# 5   6      ADHD      https://www.thuisarts.nl/adhd
# 6   7      ADHD      https://www.thuisarts.nl/adhd
# 7   8      ADHD      https://www.thuisarts.nl/adhd
# 8   9      ADHD      https://www.thuisarts.nl/adhd
# 9  10      ADHD      https://www.thuisarts.nl/adhd
#
#                                         Samenvatting  \
# 0  Een aambei is een bobbeltje aan de binnenkant ...
# 1  Een aambei is een bobbeltje aan de binnenkant ...
# 2  Een aambei is een bobbeltje aan de binnenkant ...
# 3  Iemand met ADHD kan de aandacht moeilijker erg...
# 4  Iemand met ADHD kan de aandacht moeilijker erg...
# 5  Iemand met ADHD kan de aandacht moeilijker erg...
# 6  Iemand met ADHD kan de aandacht moeilijker erg...
# 7  Iemand met ADHD kan de aandacht moeilijker erg...
# 8  Iemand met ADHD kan de aandacht moeilijker erg...
# 9  Iemand met ADHD kan de aandacht moeilijker erg...
#
#                                       Situatie_Titel  \
# 0                                    Ik heb aambeien
# 1              Er komt bloed uit mijn anus (poepgat)
# 2                            Ik wil veel vezels eten
# 3                         Mijn kind is vaak erg druk
# 4                              Heeft mijn kind ADHD?
# 5                               Mijn kind heeft ADHD
# 6     Ik denk na over ADHD-medicijnen voor mijn kind
# 7             Mijn kind gaat ADHD-medicijnen slikken
# 8  Mijn kind slikt ADHD-medicijnen en gaat een pr...
# 9                                        Ik heb ADHD
#
#                                        Situatie_Link
# 0  https://www.thuisarts.nl/aambeien/ik-heb-aambeien
# 1  https://www.thuisarts.nl/bloed-uit-anus/er-kom...
# 2  https://www.thuisarts.nl/verstopping/ik-wil-ve...
# 3  https://www.thuisarts.nl/adhd/mijn-kind-is-vaa...
# 4  https://www.thuisarts.nl/adhd/heeft-mijn-kind-...
# 5  https://www.thuisarts.nl/adhd/mijn-kind-heeft-...
# 6  https://www.thuisarts.nl/adhd/ik-denk-na-over-...
# 7  https://www.thuisarts.nl/adhd/mijn-kind-gaat-a...
# 8  https://www.thuisarts.nl/adhd/mijn-kind-slikt-...
# 9          https://www.thuisarts.nl/adhd/ik-heb-adhd
# Data van tabel: vierstroom_nieuws
#    id                                              Titel  \
# 0   1  Urgentie op sociale huurwoning voor mantelzorgers
# 1   2     Hoe kan je aantonen  dat je mantelzorger bent?
# 2   3           Wet maatschappelijke ondersteuning (Wmo)
# 3   4                          Wet langdurige zorg (Wlz)
# 4   5                               Mantelzorgwaardering
# 5   6                   Woningaanpassingen: hulpmiddelen
# 6   7        Recept: Salade met bloemkool en sinaasappel
# 7   8                          Zorgverzekeringswet (Zvw)
# 8   9                  Nieuwe editie Vierstroom Magazine
# 9  10              Heerlijke en voedzame herfstgerechten
#
#                                                 Link  \
# 0  https://www.vierstroom.nl/nieuws/539/urgentie-...
# 1  https://www.vierstroom.nl/nieuws/538/hoe-kan-j...
# 2  https://www.vierstroom.nl/nieuws/529/wet-maats...
# 3  https://www.vierstroom.nl/nieuws/532/wet-langd...
# 4  https://www.vierstroom.nl/nieuws/525/mantelzor...
# 5  https://www.vierstroom.nl/nieuws/320/woningaan...
# 6  https://www.vierstroom.nl/nieuws/534/recept-sa...
# 7  https://www.vierstroom.nl/nieuws/531/zorgverze...
# 8  https://www.vierstroom.nl/nieuws/495/nieuwe-ed...
# 9  https://www.vierstroom.nl/nieuws/562/heerlijke...
#
#                                            Image_URL  \
# 0  https://www.vierstroom.nl/thumbs/pexels-rdne-7...
# 1  https://www.vierstroom.nl/thumbs/pexels-cotton...
# 2  https://www.vierstroom.nl/thumbs/afbeelding-wm...
# 3  https://www.vierstroom.nl/thumbs/afbeelding-wl...
# 4  https://www.vierstroom.nl/thumbs/together-5928...
# 5  https://www.vierstroom.nl/thumbs/pexels-marcus...
# 6  https://www.vierstroom.nl/thumbs/winterse-sala...
# 7  https://www.vierstroom.nl/thumbs/afbeelding-zv...
# 8  https://www.vierstroom.nl/thumbs/cover-vm3-202...
# 9  https://www.vierstroom.nl/thumbs/pompoen-uitge...
#
#                                    Beschrijving_kort  \
# 0  Wil je dicht bij degene wonen voor wie je zorg...
# 1  Steeds meer gemeenten, woningbouwverenigingen ...
# 2  De Wmo is een wet die hulp en ondersteuning re...
# 3  De Wet langdurige zorg (Wlz) regelt de zorgvoo...
# 4  Als je voor iemand zorgt die dichtbij je staat...
# 5  Woningaanpassingen kunnen ervoor zorgen dat ji...
# 6  Dokter Tamara deelt graag gezonde leefstijlrec...
# 7  Dankzij de Zorgverzekeringswet (Zvw) heeft ied...
# 8  ‘Eenzaamheid is voor mij niet het gebrek aan m...
# 9  In de herfst hebben veel mensen behoefte aan i...
#
#                                    Beschrijving_lang            Categorie
# 0  Wil je dicht bij degene wonen voor wie je zorg...           Mantelzorg
# 1  Steeds meer gemeenten, woningbouwverenigingen ...           Mantelzorg
# 2  De Wmo is een wet die hulp en ondersteuning re...           Mantelzorg
# 3  De Wlz is er voor mensen die 24 uur per dag in...           Mantelzorg
# 4  Als je voor iemand zorgt die dichtbij je staat...           Mantelzorg
# 5  Woningaanpassingen kunnen ervoor zorgen dat ji...           Mantelzorg
# 6  Dokter Tamara deelt graag gezonde leefstijlrec...             Recepten
# 7  Op grond van de Zvw moet iedereen in Nederland...           Mantelzorg
# 8  Vierstroom Magazine is een magazine boordevol ...  Vierstroom Magazine
# 9  In de herfst krijgen veel mensen de behoefte a...             Recepten
# Data van tabel: workshops_zve
#    id                                 titel          organisatie  \
# 0   1                Training Goed Besturen  Gemeente Zoetermeer
# 1   2  Training Fondsenwerving I Fonds 1818  Gemeente Zoetermeer
#
#                                    beschrijving_kort  \
# 0                                               Wat?
# 1  Ben je met jouw stichting of vereniging actief...
#
#                                    beschrijving_lang             datum  \
# 0  Wat? Als bestuurder komt er nogal wat op je af...  Start 28-01-2025
# 1  Ben je met jouw stichting of vereniging actief...        18-02-2025
#
#                                            image_url  \
# 0  https://www.zoetermeervoorelkaar.nl/uploads/ca...
# 1  https://www.zoetermeervoorelkaar.nl/uploads/ca...
#
#                                        link_workshop  aantal_bijeenkomsten  \
# 0  https://www.zoetermeervoorelkaar.nl/cursusaanb...                     2
# 1  https://www.zoetermeervoorelkaar.nl/cursusaanb...                     1
#
#        eerste_bijeenkomst     laatste_bijeenkomst     inschrijven_kan_tot  \
# 0  28-01-2025 - 19:30 uur  04-03-2025 - 19:30 uur  20-01-2025 - 23:55 uur
# 1                    None                    None  14-02-2025 - 23:59 uur
#
#         datum_bijeenkomst
# 0                    None
# 1  18-02-2025 - 14:00 uur

# %%
df_IZ["Afbeelding_url"][1]
# Out:
# "data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20viewBox='0%200%20624%20312'%3E%3C/svg%3E"
